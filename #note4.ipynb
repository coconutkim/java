# %% [markdown]
# - 메소드가 결과값이 존재하면 다른 수식에 참여한다
# - 출력 대신에 예외를 발생시킨다
#
# ![image.png](attachment:image.png)
# - 박스 처리 부분은 사용자 정의 예외

# %% [markdown]
# ![image.png](attachment:image.png)
# - 예외는 코드나 사용자의 실수로 인해 발생할 수 있는 예기치 않은 상황을 처리하기 위한 것

# %% [markdown]
# # 데이터 입출력

# %% [markdown]
# - 스트림은 바이트와 문자 개념이 있다
# - 자바는 2바이트 개념을 사용한다 >> 한글 표현이 가능해진다
#
# ![image.png](attachment:image.png)
# - 이미지나 동영상은 stream 방식으로 전송한다
# - 파일을 읽는다는건 read 개념이다

# %% [markdown]
# ![image.png](attachment:image.png)
# > 데이터 입출력
# - 데이터는 키보드를 통해 입력
# - 파일 또는 프로그램으로부터 입력
# - 모니터로 출력 등등
#
# ![image-2.png](attachment:image-2.png)
# - 8비트가 모여서 1바이트가 된다
#
# ![image-3.png](attachment:image-3.png)
# - scanner로 입력받으면 저장까지 수행한다
#
# ![image-4.png](attachment:image-4.png)
# - int는 4바이트, 정수형이다
#
# ![image-5.png](attachment:image-5.png)
# - output은 말그대로 쓰기를 해서 파일로 저장을 하겠다
# - 출력을 하게 되면 모니터로 보는데 이렇게 하지 않고 파일로 저장한다 >> write
# - 파일 공간 안에 자료를 저장해라

# %% [markdown]
# - 더 이상 입력 스트림으로부터 바이트를 읽을 수 없으면 -1을 반환한다
# - 이것을 이용해서 마지막 바이트까지 한 바이트씩 읽을 수 있다
# - -1을 반환했을 경우 while문을 종료

# %% [markdown]
# ![image.png](attachment:image.png)
# - 배열 저장의 시작, 우선 선언을 해야 한다

# %% [markdown]
# ![image.png](attachment:image.png)
# - 1024는 배열을 최대 크기로 잡은 것을 의미
# - 저장하는 것이기 때문에 남는 것이 있으면 안 된다
# - flush로 내부 버퍼 잔류 바이트를 출력하고 버퍼를 비운다

# %% [markdown]
# ![image.png](attachment:image.png)
# - 스트림을 2바이트로 바꾼다

# %% [markdown]
# ![image.png](attachment:image.png)
# - 파일 입출력 데이터를 한 곳에 담아 한번에 전송을 수행한다

# %% [markdown]
# ![image.png](attachment:image.png)
# - cpu와 메모리가 뛰어나도 하드 디스크의 입출력이 늦어지면 실행 성능은 하드 디스크에 맞춰진다
# - 입출력할 때 cpu는 논다
# - 이때 도움을 주는 것이 중간에 메모리 버퍼를 작업하는 것
# - 예를 들어 사과를 1개씩 일일이 보내기 보다는 박스에 담아 빠른 속도로 배송한다
# - 버퍼를 너무 크게 잡으면 메모리 크기가 작아진다

# %% [markdown]
# - 버퍼를 사용하는 이유: 하나씩 보내기 보다는 박스에 몽땅 담아서 한번에 보내서 효율적이다
# - new bufferedreader를 작성하는건 하나의 그릇을 만들어 준비하는 것
# - system.in을 받게 되면 아스키 코드가 나온다
#
# >system.out.printf
#
# 포맷 지정자를 사용해 원하는 형식에 맞게 문자열 구성 가능
#
# ```
# System.out.printf("형식 지정자", 값1, 값2, ...);
# ```

# %% [markdown]
# - objectinputstream, objectoutputstream: 객체를 입출력할 수 있는 보조 스트림
# - 객체를 생성하면 파일로 저장한다
# - 데이터베이스를 사용하는 것은 파일 중복이 없다
# - 파일의 위치를 알면 아무나 사용할 수 있다

# %% [markdown]
# ![image.png](attachment:image.png)
# - collection은 객체를 저장하는 곳
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
# - 파일을 오픈한 후 inputstream을 통해 저장해달라
# - 분해되어 있기 때문에 어떤 객체인지 모른다
#
# - 직렬화를 하겠다고 알림

# %% [markdown]
# - 배열 안에 있는 내용을 출력할 때는 for 문
#
# ![image.png](attachment:image.png)
# - 폴더와 파일이 섞여있다
# - 조건문을 활용해서 구분지어 표시해야 한다
# - 이 과정을 통해 cmd에서 볼 수 있는 dir 명령어의 양식을 만든다

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - 맵은 파이썬의 딕셔너리처럼 키로 값을 찾는다
#
# ```
# int[] arr = new int[5]
# ```
# - 공간이 할당된다
# - arraylist는 동적 할당
#
# ![image-2.png](attachment:image-2.png)
# - E는 자료형을 나타낸다
#
# 1. 객체 생성
# 2. 객체를 임시 보관(예를 들어 바구니, 상자에)
# 3. 객체를 상자에 저장
#
# - 리스트도 일종의 상자
# - 모아서 한번에 보낸다
# - 나중에 반환값으로 받는다
# - 리스트에 요소가 얼마나 들었는지 알고 싶으면 size()
# - 리스트 안의 모든 객체를 하나씩 가져올려면 **반복문** 활용
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# - 실행하다가 join에서 잠시 쉰다
# - arraylist는 무조건 순서를 지켜야 한다

# %% [markdown]
# ![image.png](attachment:image.png)
# - 문자를 입력하면 입력이 안 되고 오류 문자 띄우기
# - 파일에 저장하기
